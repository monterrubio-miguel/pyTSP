# %% [markdown]
# # Travelling Salesman Problem
#
# The Travelling Salesman Problem describes a salesman who must travel between N cities. The order in which he does so is something he does not care about, as long as he visits each once during his trip, and finishes where he was at first. Each city is connected to other close by cities, or nodes, by airplanes, or by road or railway. Each of those links between the cities has one or more weights (or the cost) attached. The cost describes how "difficult" it is to traverse this edge on the graph, and may be given, for example, by the cost of an airplane ticket or train ticket, or perhaps by the length of the edge, or time required to complete the traversal. The salesman wants to keep both the travel costs, as well as the distance he travels as low as possible.
#
# The Traveling Salesman Problem is typical of a large class of NP-hard optimization problems that have intrigued mathematicians and computer scientists for years. Most important, it has applications in science and engineering. For example, in the manufacture of a circuit board, it is important to determine the best order in which a laser will drill thousands of holes. An efficient solution to this problem reduces production costs for the manufacturer.
#
# [Wikipedia](https://en.wikipedia.org/wiki/Travelling_salesman_problem)
#
# [Simple Wikipedia](https://simple.wikipedia.org/wiki/Travelling_salesman_problem#targetText=The%20Travelling%20Salesman%20Problem%20describes,where%20he%20was%20at%20first.)

# %% [markdown]
# ### Imports

# %%
import time
from random import uniform, shuffle
from math import sqrt, inf, factorial
from itertools import permutations
import matplotlib.pyplot as plt
from IPython.display import clear_output
# %matplotlib inline

# %% [markdown]
# ### Generate cities data

# %%
total_cities = 5

cities = [[],[]]
for i in range(total_cities):
    cities[0].append(uniform(0,1000))
    cities[1].append(uniform(0,1000))
    print(cities)

fig, axs = plt.subplots(figsize=(9,3))
xArr, yArr = cities[0], cities[1]
axs.scatter(xArr, yArr)
axs.set_xlabel(r'$x$', fontsize=15)
axs.set_ylabel(r'$y$', fontsize=15)
axs.set_title('Random Cities')

axs.grid(True)
# Out:
# [[588.5789732678804], [766.6053813997394]]
# [[588.5789732678804, 241.53227550219037], [766.6053813997394, 415.3801751338587]]
# [[588.5789732678804, 241.53227550219037, 713.6542044373941], [766.6053813997394, 415.3801751338587, 281.7154665548275]]
# [[588.5789732678804, 241.53227550219037, 713.6542044373941, 546.6634462366778], [766.6053813997394, 415.3801751338587, 281.7154665548275, 388.3560344488679]]
# [[588.5789732678804, 241.53227550219037, 713.6542044373941, 546.6634462366778, 734.8503435709516], [766.6053813997394, 415.3801751338587, 281.7154665548275, 388.3560344488679, 58.370049223107515]]

# %% [markdown]
# ## Function Declarations

# %% [markdown]
# ### Function to get the distance between two points
# $ \sqrt{(x2-x1)^2 + (y2-y1)^2} $

# %%
def dist(point1, point2):
    x1, y1, x2, y2 = point1[0], point1[1], point2[0], point2[1]
    return sqrt((x2-x1)**2 + (y2-y1)**2)

# %% [markdown]
# ### Function to shuffle cities

# %%
def shuffle_cities(cities):
    xArr, yArr = cities[0], cities[1]
    points = list(zip(xArr, yArr))
    shuffle(points)
    cities[0], cities[1] = zip(*points)
    return cities

# %% [markdown]
# ### Function to calculate the sum of the distance between cities

# %%
def calculate_distance(cities):
    accum = 0
    xArr, yArr = cities[0], cities[1]
    for i in range(len(xArr)-1):
        point1, point2 = (xArr[i], yArr[i]), (xArr[i+1], yArr[i+1])
        accum += dist(point1, point2)
    return accum

# %% [markdown]
# ### Function to obtain closest city

# %%
def get_closest(point1, cities, visited):
    best_distance = float('Inf')
    for i, coord in enumerate(cities[0]):
        if i not in visited:
            distance = dist((cities[0][point1], cities[1][point1]), (cities[0][i], cities[1][i]))
                            
            if distance < best_distance:
                closest = i
                best_distance = distance
        if point1==len(cities[0])-1:
            closest = visited[0]
                
    return closest, best_distance

# %% [markdown]
# ### Function to plot an iteration and plot current optimum distance

# %%
def plot_iteration_and_optimum(cities, record_cities, eval_number, distance, record_distance):
    clear_output(wait=True)
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))
    iteration_plt, = axs[0], axs[1]
    
    # Plot each iteration with red
    for i in range(len(cities[0]) - 1): iteration_plt.plot(cities[0][i:i+2], cities[1][i:i+2], 'ro-')
    iteration_plt.plot([cities[0][-1], cities[0][0]],[cities[1][-1], cities[1][0]],'ro-')
    iteration_plt.set_title(f'Every Iteration\nDistance: {distance} \nEvaluation no. {eval_number}')
    
    # Plot the current optimum
    for i in range(len(record_cities[0]) - 1): optimum_plt.plot(record_cities[0][i:i+2], record_cities[1][i:i+2], 'go-')
    optimum_plt.plot([record_cities[0][-1], record_cities[0][0]],[record_cities[1][-1], record_cities[1][0]],'go-')
    optimum_plt.set_title(f'Current Optimum\nDistance: {record_distance}\nEvaluation no. {eval_number}')
        
    plt.show();

# %% [markdown]
# ### Function to plot informed search algorithms
# I have no idea if this works

# %%
def plot_greedy(cities, step_number, distance):
    clear_output(wait=True)
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))
    iteration_plt, optimum_plt = axs[0], axs[1]
    
    # Plot each iteration with red
    for i in range(len(cities[0]) - 1): iteration_plt.plot(cities[0][i:i+2], cities[1][i:i+2], 'ro-')
    iteration_plt.plot([cities[0][-1], cities[0][0]],[cities[1][-1], cities[1][0]],'ro-')
    iteration_plt.set_title(f'Distance: {distance} \nStep no. {step_number}')
        
    plt.show();

# %% [markdown]
# ### Random Shuffle
# Shuffle randomly to get the best possible answer

# %%
def shuffle(iterations=0):
    record_distance = inf
    for i in range(iterations):
        current_distance = calculate_distance(cities)
        if current_distance < record_distance:
            record_distance = current_distance
            record_cities = cities.copy()
        plot_iteration_and_optimum(cities, record_cities, eval_number=i+1, distance=current_distance, record_distance=record_distance)
        shuffle_cities(cities)
shuffle(iterations=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-0842c1318bb1> in <module>
#       8         plot_iteration_and_optimum(cities, record_cities, eval_number=i+1, distance=current_distance, record_distance=record_distance)
#       9         shuffle_cities(cities)
# ---> 10 shuffle(iterations=100)
#
# <ipython-input-12-0842c1318bb1> in shuffle(iterations)
#       7             record_cities = cities.copy()
#       8         plot_iteration_and_optimum(cities, record_cities, eval_number=i+1, distance=current_distance, record_distance=record_distance)
# ----> 9         shuffle_cities(cities)
#      10 shuffle(iterations=100)
#
# <ipython-input-4-219b5fe56757> in shuffle_cities(cities)
#       2     xArr, yArr = cities[0], cities[1]
#       3     points = list(zip(xArr, yArr))
# ----> 4     shuffle(points)
#       5     cities[0], cities[1] = zip(*points)
#       6     return cities
#
# <ipython-input-12-0842c1318bb1> in shuffle(iterations)
#       1 def shuffle(iterations=0):
#       2     record_distance = inf
# ----> 3     for i in range(iterations):
#       4         current_distance = calculate_distance(cities)
#       5         if current_distance < record_distance:
#
# TypeError: 'list' object cannot be interpreted as an integer

# %% [markdown]
# ### Brute Force
# Get all permutations of the cities and test all possible combinations
# Where all possible combinations is: $ factorial(nCities) $

# %%
print(f'Number of iterations = factorial({total_cities}) = {factorial(total_cities)}')

# %%
def brute():
    record_distance = inf
    eval_number = 0
    for permutation in permutations(list(zip(cities[0],cities[1]))):
        eval_number += 1
        permutation = list(permutation)
        cities[0], cities[1] = zip(*permutation)
        current_distance = calculate_distance(cities)
        if current_distance < record_distance:
            record_distance = current_distance
            record_cities = cities.copy()
        plot_iteration_and_optimum(cities, record_cities, eval_number=eval_number, distance=current_distance, record_distance=record_distance)
        
brute()

# %% [markdown]
# ### Informed Search
# #### Greedy
# Goes for the closest city at each step

# %%
def greedy():
    length = 0
    best_length = inf
    order = [0]
    best_order = []
    steps_taken = 0
    cities_visited = [[],[]]
    for i, city in enumerate(cities[0]):
        closest, distance = get_closest(order[i],cities,order)
        length += distance
        order.append(closest)
        cities_visited[0].append(cities[0][closest])
        cities_visited[1].append(cities[1][closest])
        steps_taken += 1
        
        plot_greedy(cities_visited, steps_taken, length)
greedy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-49160857d96b> in <module>
#      15
#      16         plot_greedy(cities_visited, steps_taken, length)
# ---> 17 greedy()
#
# <ipython-input-29-49160857d96b> in greedy()
#      14         steps_taken += 1
#      15
# ---> 16         plot_greedy(cities_visited, steps_taken, length)
#      17 greedy()
#
# <ipython-input-28-1afd088c174f> in plot_greedy(cities, step_number, distance)
#       1 def plot_greedy(cities, step_number, distance):
#       2     clear_output(wait=True)
# ----> 3     plt.plot(1, 1, figsize=(12, 6))
#       4     plt.subplot(111)
#       5
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     403                 "non-matching shapes is deprecated.")
#     404         for j in range(max(ncx, ncy)):
# --> 405             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     406             ret.append(seg)
#     407         return ret
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     310         default_dict = self._getdefaults(set(), kw)
#     311         self._setdefaults(default_dict, kw)
# --> 312         seg = mlines.Line2D(x, y, **kw)
#     313         return seg
#     314
#
# ~/.local/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         # update kwargs before updating data to give the caller a
#     403         # chance to init axes (and hence unit support)
# --> 404         self.update(kwargs)
#     405         self.pickradius = pickradius
#     406         self.ind_offset = 0
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'Line2D' object has no property 'figsize'
